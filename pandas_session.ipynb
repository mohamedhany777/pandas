# %%
import pandas as pd

# %%
series= pd.Series([10,20,30,40])
print (series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data = {  'name':['alice','bob','charlie'],
          'age':[25,30,35],
           'city':['new yourk', 'los angeles' ,'chicago']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       name  age         city
# 0    alice   25    new yourk
# 1      bob   30  los angeles
# 2  charlie   35      chicago

# %%
df.head()
# Out:
#       name  age         city
# 0    alice   25    new yourk
# 1      bob   30  los angeles
# 2  charlie   35      chicago

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   city    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#         age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
df['name']
# Out:
# 0      alice
# 1        bob
# 2    charlie
# Name: name, dtype: object

# %%
filtered_df = df[df['age']>30]
filtered_df
# Out:
#       name  age     city
# 2  charlie   35  chicago

# %%
salected_data=df.loc[0:2,['name','city']]
salected_data
# Out:
#       name         city
# 0    alice    new yourk
# 1      bob  los angeles
# 2  charlie      chicago

# %%
df2=pd.DataFrame( [[1,2,3],['true','true','false'],[0.44,0.22,0.62]] ,index=['a','b','c'] ,columns=['A','B','C'] )
df2
# Out:
#       A     B      C
# a     1     2      3
# b  true  true  false
# c  0.44  0.22   0.62

# %%
df2.loc['a':'b',['B','C']]
# Out:
#       B      C
# a     2      3
# b  true  false

# %%
# iloc[] ===> we should use the index only to search an items .

df2.iloc[0:2,[1,2]]
# Out:
#       B      C
# a     2      3
# b  true  false

# %%
# to add a columns .

df['salary']=[70000,80000,90000]
df
# Out:
#       name  age         city  salary
# 0    alice   25    new yourk   70000
# 1      bob   30  los angeles   80000
# 2  charlie   35      chicago   90000

# %%
df['age']=df['age']+ 1
df
# Out:
#       name  age         city  salary
# 0    alice   26    new yourk   70000
# 1      bob   31  los angeles   80000
# 2  charlie   36      chicago   90000

# %%
df=df.drop('city',axis=1)
df
# Out:
#       name  age  salary
# 0    alice   26   70000
# 1      bob   31   80000
# 2  charlie   36   90000

# %%
df_with_nan=pd.DataFrame({
'A':[1,2,pd.NA ],
'B':[4,pd.NA ,6]

} )
df_with_nan.isna()
# Out:
#        A      B
# 0  False  False
# 1  False   True
# 2   True  False

# %%
filled_df=df_with_nan.fillna(0)
filled_df
# Out:
# <ipython-input-17-8cae8a17b2dd>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   filled_df=df_with_nan.fillna(0)
#    A  B
# 0  1  4
# 1  2  0
# 2  0  6

# %%
df_with_nan['A']=df_with_nan['A'].fillna(df_with_nan['A'].mean())
df_with_nan
# Out:
# <ipython-input-18-bf6dfcc3fd06>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_with_nan['A']=df_with_nan['A'].fillna(df_with_nan['A'].mean())
#      A     B
# 0  1.0     4
# 1  2.0  <NA>
# 2  1.5     6

# %%
cleaned_df=df_with_nan.dropna()
cleaned_df
# Out:
#      A  B
# 0  1.0  4
# 2  1.5  6

# %%
df3=pd.DataFrame({
'department':['hr','it','hr','it'],
'salary':[50000,60000,45000,80000]
})
grouped=df3.groupby('department').mean()
print(grouped)
# Out:
#              salary
# department
# hr          47500.0
# it          70000.0
